# %%
import requests

# %%
url = 'https://api.binance.com/api/v3/trades?symbol=BNBUSDT'
response = requests.get(url)
response.json()
# Out:
# [{'id': 496737162,
#   'price': '512.20000000',
#   'qty': '0.02100000',
#   'quoteQty': '10.75620000',
#   'time': 1641329170287,
#   'isBuyerMaker': True,
#   'isBestMatch': True},
#  {'id': 496737163,
#   'price': '512.20000000',
#   'qty': '3.90500000',
#   'quoteQty': '2000.14100000',
#   'time': 1641329171485,
#   'isBuyerMaker': True,
#   'isBestMatch': True},
#  {'id': 496737164,
#   'price': '512.20000000',
#   'qty': '0.05200000',
#   'quoteQty': '26.63440000',
#   'time': 1641329171485,
#   'isBuyerMaker': True,
#   'isBestMatch': True},
#  {'id': 496737165,
#   'price': '512.10000000',
#   'qty': '0.10900000',
#   'quoteQty': '55.81890000',
#   'time': 1641329171515,
#   'isBuyerMaker': True,
#   'isBestMatch': True},
#  {'id': 496737166,
#   'price': '512.20000000',
#   'qty': '19.71900000',
#   'quoteQty': '10100.07180000',
#   'time': 1641329171562,
#   'isBuyerMaker': False,
#   'isBestMatch': True},
#  {'id': 496737167,
#   'price': '512.20000000',
# ...
